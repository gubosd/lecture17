# %% [markdown]
# ## 신경망과 딥러닝
# # 케라스(Keras) 기본
# - 케라스는 텐서플로, Theano, CNTK, MSNet 을 백엔드로 사용한다
# - 즉, 기존 신경망 엔진 위에서 편리한 인터페이스를 제공한다
# - tensorflow 2.x 부터는 텐서플로에 포함됨

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow import keras

# %%
keras.__version__
# Out:
# '2.4.0'

# %% [markdown]
# ### 케라스 맛보기 (회귀)
# - 출력층 활성화함수 : 없음
# - 비용함수 : MSE

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x = np.array([1,2,3])
y = np.array([3,5,9])

# %%
model = Sequential()
model.add(Dense(1, input_shape=(1,))) # 'linear' is default

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer='sgd')
model.fit(x.reshape(-1,1), y, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 1s 528ms/step - loss: 10.8948
# Epoch 2/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 8.6815
# Epoch 3/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 6.9320
# Epoch 4/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 5.5489
# Epoch 5/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 4.4556
# Epoch 6/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.5912
# Epoch 7/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9079
# Epoch 8/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.3676
# Epoch 9/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.9405
# Epoch 10/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.6028
# Epoch 11/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.3357
# Epoch 12/1000
# ...

# %%
plt.plot(model.history.history['loss'])

# %%
model.predict(x.reshape(-1,1))
# Out:
# array([[2.7115262],
#        [5.676294 ],
#        [8.641062 ]], dtype=float32)

# %%
plt.scatter(x, y)
plt.plot(x, model.predict(x.reshape(-1,1)).ravel(), 'r--')
plt.axis('equal')
# Out:
# (0.9, 3.1, 2.3971024632453917, 9.31442369222641)

# %%
ws = model.get_weights()
ws
# Out:
# [array([[2.9516075]], dtype=float32), array([-0.22332627], dtype=float32)]

# %%
w = ws[0][0,0]
b = ws[1][0]
w, b
# Out:
# (2.9516075, -0.22332627)

# %% [markdown]
# ### 케라스 맛보기 (이진분류)
# - 출력층 활성화함수 : sigmoid
# - 비용함수 : binary_crossentropy
# > $$ cost = -\frac{1}{N} \cdot \sum_{i=0}^{N-1} [y_i \log(\hat{y_i}) + (1-y_i) \log(1-\hat{y_i})] $$

# %%
3840*2160*3 # 25Mb
# Out:
# 24883200

# %% [markdown]
# <img src="https://donarthurzhang.files.wordpress.com/2017/08/screen-shot-2017-08-11-at-6-41-57-pm.png?w=1024" /><br>
# (출처: https://projectsig.com/2017/08/11/logistic-regression-with-a-neural-network-cat-recognizer/)

# %%
X = np.array([[0,0],[0,2],[2,0]])
y = np.array([0,1,1])

plt.scatter(X[:,0], X[:,1], c=y, s=100)
plt.axis('equal')
# Out:
# (-0.1, 2.1, -0.1, 2.1)

# %%
model = Sequential()
model.add(Dense(1, input_shape=(2,), activation='sigmoid'))

# %%
from tensorflow.keras.optimizers import SGD # lr=0.01

# %%
model.compile(loss='binary_crossentropy', optimizer=SGD(lr=1),
              metrics=['acc'])
history = model.fit(X, y, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 283ms/step - loss: 1.0680 - acc: 0.6667
# Epoch 2/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.7083 - acc: 0.3333
# Epoch 3/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5071 - acc: 0.6667
# Epoch 4/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4186 - acc: 0.6667
# Epoch 5/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3704 - acc: 0.6667
# Epoch 6/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3366 - acc: 0.6667
# Epoch 7/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3097 - acc: 1.0000
# Epoch 8/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2871 - acc: 1.0000
# Epoch 9/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2675 - acc: 1.0000
# Epoch 10/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2503 - acc: 1.0000
# Epoch 11/1000
# ...

# %%
pred_y = model.predict(X)
pred_y
# Out:
# WARNING:tensorflow:5 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001B9F3908EE8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# array([[0.0060805 ],
#        [0.9984824 ],
#        [0.99848205]], dtype=float32)

# %%
((pred_y.ravel()>0.5)==y).mean()
# Out:
# 1.0

# %%
plt.plot(history.history['loss'])

# %%
ws = model.get_weights()
ws
# Out:
# [array([[5.792719 ],
#         [5.7928143]], dtype=float32),
#  array([-5.096569], dtype=float32)]

# %%
w1 = ws[0][0,0]
w2 = ws[0][1,0]
b = ws[1][0]
w1,w2,b
# Out:
# (5.792719, 5.7928143, -5.096569)

# %%
plt.scatter(X[:,0], X[:,1], c=y, s=100)
rng = np.array([-1,2])
plt.plot(rng, -(w1*rng+b)/w2)
plt.axis('equal')
# Out:
# (-1.15, 2.15, -1.2761661688786978, 2.1560079128037475)

# %% [markdown]
# ### 케라스 활용정보
# - 케라스 설정파일 : C:/Users/[사용자아이디]/.keras/keras.json
# - 데이터셋 폴더 : C:/Users/[사용자아이디]/.keras/datasets
# - 홈페이지 : http://keras.io
# - input_shape=(30,) 또는 input_dim=30
# - activation : softmax, relu, tanh, sigmoid (https://keras.io/activations/)
# <br><br>
# - Sequencial 가이드 : https://keras.io/getting-started/sequential-model-guide/
# - optimizer : sgd, rmsprop, adagrad, adam (https://keras.io/optimizers/)
# - loss : mse, mae, categorical_crossentropy, binary_crossentropy (https://keras.io/losses/)
# - compile, fit 함수 설명 : https://keras.io/models/sequential/
# <br><br>
# - keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=None, decay=0.0)
# - keras.optimizers.SGD(lr=0.01, momentum=0.0, decay=0.0, nesterov=False)
# - keras.optimizers.Adagrad(lr=0.01, epsilon=None, decay=0.0)
